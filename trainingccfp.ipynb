# %%
import torch
import os
from PIL import Image
print("Python:", os.popen("python3 --version").read().strip())
print("PyTorch:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
print("Current Dir:", os.getcwd())
print("PACS Contents:", os.listdir("./data/data/PACS/PACS"))
img = Image.open("./data/data/PACS/PACS/cartoon/horse/dct_pic_003.jpg")
print("Test image loaded successfully")
# Out:
# Python: Python 3.8.20
# PyTorch: 2.4.1+cu121
# CUDA Available: True
# Current Dir: /home/user/ccfp/CCFP
# PACS Contents: ['art_painting', 'sketch', 'cartoon', 'photo']
# Test image loaded successfully

# %%
# !python3 train.py --data_dir ./data/data/PACS --dataset PACS --algorithm CCFP --output_dir ./outputs/train_2_epochs --test_envs 0 --trial_seed 1
# Out:
# Environment:
# 	Python: 3.8.20
# 	PyTorch: 2.4.1+cu121
# 	Torchvision: 0.19.1+cu121
# 	CUDA: 12.1
# 	CUDNN: 90100
# 	NumPy: 1.24.3
# 	PIL: 10.4.0
# Args:
# 	algorithm: CCFP
# 	checkpoint_freq: None
# 	data_dir: ./data/data/PACS
# 	dataset: PACS
# 	holdout_fraction: 0.2
# 	hparams: None
# 	hparams_seed: 0
# 	output_dir: ./outputs/train_2_epochs
# 	save_model_every_checkpoint: False
# 	seed: 0
# 	skip_model_save: False
# 	steps: None
# 	task: domain_generalization
# 	test_envs: [0]
# 	trial_seed: 1
# 	uda_holdout_fraction: 0
# HParams:
# 	MNIST_CNN: False
# 	batch_size: 1
# 	class_balanced: False
# 	data_augmentation: True
# 	lambda_dis: 0.0
# 	lambda_sem: 0.0
# 	lr: 5e-05
# 	nonlinear_classifier: False
# 	resnet18: False
# 	resnet_dropout: 0.0
# 	weight_decay: 0.0
# Using device: cuda
# ...
